# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('academic_data.csv')
test = pd.read_csv('test.csv')
sample = pd.read_csv('sample_submission.csv')

# %%
train.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 1                  1    9238
# 1               1                17                  1    9238
# 2               1                17                  2    9254
# 3               1                 1                  3    9500
# 4               1                 1                  2    9500
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           126.0            1                       1
# 1                           125.0            1                      19
# ...

# %%
test.head()
# Out:
#       id  Marital status  Application mode  Application order  Course  \
# 0  76518               1                 1                  1    9500
# 1  76519               1                 1                  1    9238
# 2  76520               1                 1                  1    9238
# 3  76521               1                44                  1    9147
# 4  76522               1                39                  1    9670
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                      39
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  ...  \
# 0                           141.0            1                       3  ...
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51012 entries, 0 to 51011
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              51012 non-null  int64
#  1   Marital status                                  51012 non-null  int64
#  2   Application mode                                51012 non-null  int64
#  3   Application order                               51012 non-null  int64
#  4   Course                                          51012 non-null  int64
#  5   Daytime/evening attendance                      51012 non-null  int64
#  6   Previous qualification                          51012 non-null  int64
#  7   Previous qualification (grade)                  51012 non-null  float64
#  8   Nacionality                                     51012 non-null  int64
# ...

# %%
test.isnull().sum()
# Out:
# id                                                0
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# ...

# %%
train.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# ...

# %%
test.drop(columns=['id'],inplace = True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76518 entries, 0 to 76517
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  76518 non-null  int64
#  1   Application mode                                76518 non-null  int64
#  2   Application order                               76518 non-null  int64
#  3   Course                                          76518 non-null  int64
#  4   Daytime/evening attendance                      76518 non-null  int64
#  5   Previous qualification                          76518 non-null  int64
#  6   Previous qualification (grade)                  76518 non-null  float64
#  7   Nacionality                                     76518 non-null  int64
#  8   Mother's qualification                          76518 non-null  int64
# ...

# %%
train.shape
# Out:
# (76518, 37)

# %%
test.shape
# Out:
# (51012, 36)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
x = train.drop(columns=['Target'],axis=1)
y = train['Target']

# %%
x_train,x_val,y_train,y_val = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)
x_test = scaler.transform(test)

# %% [markdown]
# ### Creating the model

# %% [markdown]
# ### Gradient boosting.

# %%
# modelgb =GradientBoostingClassifier(n_estimators=150,learning_rate=0.12,loss='log_loss',verbose=0,max_depth=5,criterion='squared_error')
# modelgb.fit(x_train,y_train)
# ygb = modelgb.predict(x_val)
# accuracy_score(y_val,ygb)*100

# %%
# a = accuracy_score(y_val,ygb)*100

# %% [markdown]
# ### adaboosting

# %%
# modelad = AdaBoostClassifier()
# modelad.fit(x_train,y_train)
# yad = modelad.predict(x_val)
# accuracy_score(y_val,yad)*100

# %%
# estimators = [

#     ('gbdt', GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3)),
#     ('ad', AdaBoostClassifier(n_estimators=140,learning_rate=0.2))

# ]

# %%
# from sklearn.ensemble import StackingClassifier

# %%
# clf = StackingClassifier(
#     estimators=estimators, 
#     final_estimator=RandomForestClassifier(),
#     cv=10
# )

# %%
# clf.fit(x_train,y_train)

# %%
# stc = clf.predict(x_val)

# %%
# accuracy_score(y_val,stc)*100

# %% [markdown]
# #### new model

# %%
# svm  =SVC()
# svm.fit(x_train,y_train)
# zz = svm.predict(x_val)
# accuracy_score(y_val,zz)*100

# %%
# ygb

# %%
# predi = modelgb.predict(x_test)

# %%
# predi

# %%
# sample['Target'] = predi

# %%
# sample

# %%
# tar ={1:'Graduate',2:'Dropout',3:'Enrolled'}
# sample['Target'] = sample['Target'].map(tar)

# %%
# sample.to_csv('submission.csv',index= False)

# %%
# pip install lightgbm

# %%
# import lightgbm as lgb

# %% [markdown]
# #### testing a new model

# %%
# from sklearn.ensemble import VotingClassifier
# from sklearn.linear_model import LogisticRegression
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.svm import SVC
# log_clf = LogisticRegression()
# tree_clf = DecisionTreeClassifier()
# svm_clf = SVC(probability=True)  

# voting_clf = VotingClassifier(
#     estimators=[('lr', log_clf), ('dt', tree_clf), ('svc', svm_clf)],
#     voting='soft'  
# )
# voting_clf.fit(x_train, y_train)

# %%
# pro = voting_clf.predict(x_val)

# %%
# accuracy_score(y_val,pro)*100

# %% [markdown]
# #### new model

# %%
from catboost import CatBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)

# %% [markdown]
# #### Create model from here.

# %%
xgb = XGBClassifier(n_estimators = 500, learning_rate = 0.01, max_depth = 4,n_jobs=-1,gamma=8)
xgb.fit(x_train, y_train)
xgb.predict(x_val)
accuracy_score(y_val.values,xgb.predict(x_val))*100
# Out:
# 4.377940407736539

# %%
predicationcat = clfstack.predict(x_test)

# %%
sample['Target'] = predicationcat

# %%
catmap = {0:'Graduate',1:'Dropout',2:'Enrolled'}
sample['Target'] = sample['Target'].map(catmap)

# %%
sample.to_csv('submission.csv',index = False)

# %%
pip install lightgbm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import lightgbm as lgb

# %%
import lightgbm as lgb
clf = lgb.LGBMClassifier(boosting_type='gbdt'importance_type='split', learning_rate=0.01, max_depth=4,
               n_estimators=150, n_jobs=-1,
               random_state=42, silent=True,
               )
clf.fit(x_train, y_train)
# Out:
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1397
# [LightGBM] [Info] Number of data points in the train set: 61214, number of used features: 36
# [LightGBM] [Info] Start training from score -0.746287
# [LightGBM] [Info] Start training from score -1.105333
# [LightGBM] [Info] Start training from score -1.635907
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
clf.predict(x_val)
# Out:
# [LightGBM] [Warning] Unknown parameter: silent
# array([0, 1, 2, ..., 0, 0, 0], dtype=int64)

# %%
accuracy_score(y_val,clf.predict(x_val))*100
# Out:
# [LightGBM] [Warning] Unknown parameter: silent
# 4.286461055933089

# %%
estimators = [
    ('xgb', XGBClassifier(n_estimators=500, learning_rate=0.01, max_depth=4, n_jobs=-1, gamma=8)),
    ('cat', CatBoostClassifier(iterations=1500, learning_rate=0.01, depth=6))
]

# %%
from sklearn.ensemble import StackingClassifier
clfstack = StackingClassifier(
    estimators=estimators, 
    final_estimator=LogisticRegression(),
    cv=10
)

# %%
clfstack.fit(x_train,y_train)
# Out:
# 0:	learn: 1.0875461	total: 42.5ms	remaining: 1m 3s
# 1:	learn: 1.0768396	total: 72.5ms	remaining: 54.3s
# 2:	learn: 1.0663068	total: 102ms	remaining: 50.7s
# 3:	learn: 1.0562306	total: 130ms	remaining: 48.7s
# 4:	learn: 1.0462584	total: 157ms	remaining: 47s
# 5:	learn: 1.0363657	total: 184ms	remaining: 45.8s
# 6:	learn: 1.0269354	total: 212ms	remaining: 45.2s
# 7:	learn: 1.0176365	total: 246ms	remaining: 45.9s
# 8:	learn: 1.0087456	total: 280ms	remaining: 46.3s
# 9:	learn: 1.0000179	total: 310ms	remaining: 46.1s
# 10:	learn: 0.9913588	total: 336ms	remaining: 45.5s
# 11:	learn: 0.9827855	total: 365ms	remaining: 45.2s
# 12:	learn: 0.9744078	total: 392ms	remaining: 44.8s
# 13:	learn: 0.9663774	total: 420ms	remaining: 44.5s
# 14:	learn: 0.9583849	total: 449ms	remaining: 44.5s
# 15:	learn: 0.9505893	total: 479ms	remaining: 44.5s
# 16:	learn: 0.9430495	total: 507ms	remaining: 44.2s
# 17:	learn: 0.9355070	total: 534ms	remaining: 44s
# 18:	learn: 0.9282949	total: 561ms	remaining: 43.7s
# ...

# %%
clfstack.predict(x_val)
# Out:
# array([0, 1, 2, ..., 0, 0, 0], dtype=int64)

# %%
accuracy_score(y_val,clfstack.predict(x_val))*100
# Out:
# 4.103502352326189
